# %%
import pandas as pd
import numpy as np
from preprocess import insta_open

# %%
! pwd
# Out:
# /Users/alexromero/Documents/Rel8

# %% [markdown]
# # Load in data

# %%
data = pd.read_json('./newyorkcity/newyorkcity.json')

# %%
data.head()
# Out:
#    __typename                                           comments  \
# 0  GraphImage  {'data': [{'created_at': 1539826120, 'id': '17...
# 1  GraphImage  {'data': [{'created_at': 1539045204, 'id': '17...
# 2  GraphImage  {'data': [{'created_at': 1537482224, 'id': '17...
# 3  GraphImage  {'data': [{'created_at': 1538077061, 'id': '17...
# 4  GraphImage  {'data': [{'created_at': 1534883372, 'id': '17...
#
#    comments_disabled                       dimensions  \
# 0              False  {'height': 1350, 'width': 1080}
# 1              False  {'height': 1080, 'width': 1080}
# 2              False  {'height': 1350, 'width': 1080}
# 3              False  {'height': 1350, 'width': 1080}
# 4              False  {'height': 1349, 'width': 1080}
#
#                                          display_url edge_media_preview_like  \
# 0  https://scontent-lga3-1.cdninstagram.com/vp/57...        {'count': 35749}
# 1  https://scontent-lga3-1.cdninstagram.com/vp/5d...        {'count': 50269}
# ...

# %% [markdown]
# # Preprocessing -- load in json data to insta_open preprocessing function.

# %%
df = insta_open('./newyorkcity/newyorkcity.json')
df.head()
# Out:
#     comment_timestamp         comment_id comment_user_id  \
# 0 2018-10-17 21:28:40  17975466769101615      8705972523
# 1 2018-10-18 01:49:35  17891628391266456       359771542
# 2 2018-10-18 03:46:31  17991032293001043       485124896
# 3 2018-10-19 13:19:52  17975796661101722      8902677546
# 4 2018-10-19 18:59:41  17975730259103091      8723523941
#
#                                         comment_text              post_id  \
# 0  👋👋👋👋👋👋👋👋👋👋👋👋New store fashion online just foll...  1884387397867461120
# 1                                      @ervinacovcic  1884387397867461120
# 2         Nearly as beautiful as @travelnewzealand 😉  1884387397867461120
# 3                                                  🙄  1884387397867461120
# 4                         Beatiful pic ! Very nice !  1884387397867461120
#
#   post_type  post_likes                                          post_text  \
# 0     Image       35749  Use your voice. Turn your anger into action. V...
# ...

# %%
df.shape
# Out:
# (10333, 17)

# %%
df.to_csv('newyorkcity.csv', index=False)
